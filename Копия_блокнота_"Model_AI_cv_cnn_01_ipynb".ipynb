# %% [markdown]
# <a href="https://colab.research.google.com/github/NikolayIvTkachenko/Colab_Python_AI_NeuroNetwork/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Model_AI_cv_cnn_01_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Вспомогательные ссылки на картинки и не только
#https://tfhub.dev/tensorflow/collections/object_detection/
#https://www.pexels.com/photo/man-on-white-horse-next-to-dog-on-grassy-field-162520/.
#
#
#
#
#

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import tensorflow as tf
import tensorflow_hub as hub

# %%
img = cv2.imread('horse.jpg')
img = cv2.resize(img, dsize=(540, 640))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=540x640>
